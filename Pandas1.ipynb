# %%
person = {
    "first" : "Haseeb",
    "last" : "Tariq",
    "email" : "haseebtariq@gmail.com"
}

# %%
people = {
    "first" : ["Haseeb"],
    "last" : ["Tariq"],
    "email" : ["haseebtariq@gmail.com"]
}

# %%
people = {
    "first" : ["Haseeb", "Ali", "Sharjeel"],
    "last" : ["Tariq", "Ahmad", "Ikhlaq"],
    "email" : ["haseebtariq@gmail.com", "aliahmad@gmail.com", "sharjeelikhlaq@gmail.com"]
}

# %%
people["email"]
# Out:
# ['haseebtariq@gmail.com', 'aliahmad@gmail.com', 'sharjeelikhlaq@gmail.com']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 1       Ali   Ahmad        aliahmad@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.email
# Out:
# 0       haseebtariq@gmail.com
# 1          aliahmad@gmail.com
# 2    sharjeelikhlaq@gmail.com
# Name: email, dtype: str

# %%
df[['last', 'email']]
# Out:
#      last                     email
# 0   Tariq     haseebtariq@gmail.com
# 1   Ahmad        aliahmad@gmail.com
# 2  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[[0, 1], 2]
# Out:
# 0    haseebtariq@gmail.com
# 1       aliahmad@gmail.com
# Name: email, dtype: str

# %%
df.loc[0]
# Out:
# first                   Haseeb
# last                     Tariq
# email    haseebtariq@gmail.com
# Name: 0, dtype: str

# %%
# df.loc[[0,1], ['email', 'last']]

# %%
df['email']
# Out:
# 0       haseebtariq@gmail.com
# 1          aliahmad@gmail.com
# 2    sharjeelikhlaq@gmail.com
# Name: email, dtype: str

# %%
# df.set_index('email', inplace=True)

# %%
df
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 1       Ali   Ahmad        aliahmad@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
# df.index

# %%
# df.loc['haseebtariq@gmail.com', 'last']

# %%
df.iloc[0]
# Out:
# first                   Haseeb
# last                     Tariq
# email    haseebtariq@gmail.com
# Name: 0, dtype: str

# %%
df
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 1       Ali   Ahmad        aliahmad@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
# df.reset_index(inplace=True)

# %%
# filt = (df['last'] == 'Ikhlaq') & (df['first'] == 'Haseeb')
filt = (df['last'] == 'Ikhlaq') | (df['first'] == 'Haseeb')

# %%
df[filt]
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.loc[~filt, 'email']
# Out:
# 1    aliahmad@gmail.com
# Name: email, dtype: str

# %%
df.columns = ['first_name', 'last_name', 'email']
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='str')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'EMAIL'], dtype='str')

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                     EMAIL
# 0     Haseeb     Tariq     haseebtariq@gmail.com
# 1        Ali     Ahmad        aliahmad@gmail.com
# 2   Sharjeel    Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name                     email
# 0     Haseeb     Tariq     haseebtariq@gmail.com
# 1        Ali     Ahmad        aliahmad@gmail.com
# 2   Sharjeel    Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.rename(columns={'first_name' : 'first', 'last_name' : 'last'}, inplace=True)

# %%
df
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 1       Ali   Ahmad        aliahmad@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.loc[1] = ['Zeeshan', 'Jamal', 'zeeshan@gmail.com']

# %%
df
# Out:
#       first    last                     email
# 0    Haseeb   Tariq     haseebtariq@gmail.com
# 1   Zeeshan   Jamal         zeeshan@gmail.com
# 2  Sharjeel  Ikhlaq  sharjeelikhlaq@gmail.com

# %%
df.loc[2, ['last', 'email']] = ['Hussain', 'Sharjeel@gmail.com']

# %%
df
# Out:
#       first     last                  email
# 0    Haseeb    Tariq  haseebtariq@gmail.com
# 1   Zeeshan    Jamal      zeeshan@gmail.com
# 2  Sharjeel  Hussain     Sharjeel@gmail.com

# %%
df.loc[2, 'last'] = 'Sheikh'
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  haseebtariq@gmail.com
# 1   Zeeshan   Jamal      zeeshan@gmail.com
# 2  Sharjeel  Sheikh     Sharjeel@gmail.com

# %%
df.at[2, 'last'] = 'Sheikh'
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  haseebtariq@gmail.com
# 1   Zeeshan   Jamal      zeeshan@gmail.com
# 2  Sharjeel  Sheikh     Sharjeel@gmail.com

# %%
filt = (df['email'] == 'sharjeel@gmail.com')
df[filt]['last']
# Out:
# Series([], Name: last, dtype: str)

# %%
filt = (df['email'] == 'sharjeel@gmail.com')
df.loc[filt, 'last'] = 'Ikhklaq'

# %%
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  haseebtariq@gmail.com
# 1   Zeeshan   Jamal      zeeshan@gmail.com
# 2  Sharjeel  Sheikh     Sharjeel@gmail.com

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  haseebtariq@gmail.com
# 1   Zeeshan   Jamal      zeeshan@gmail.com
# 2  Sharjeel  Sheikh     sharjeel@gmail.com

# %%
df['email'].apply(len)
# Out:
# 0    21
# 1    17
# 2    18
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    HASEEBTARIQ@GMAIL.COM
# 1        ZEESHAN@GMAIL.COM
# 2       SHARJEEL@GMAIL.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  HASEEBTARIQ@GMAIL.COM
# 1   Zeeshan   Jamal      ZEESHAN@GMAIL.COM
# 2  Sharjeel  Sheikh     SHARJEEL@GMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#       first    last                  email
# 0    Haseeb   Tariq  haseebtariq@gmail.com
# 1   Zeeshan   Jamal      zeeshan@gmail.com
# 2  Sharjeel  Sheikh     sharjeel@gmail.com

# %%
df['email'].apply(len)
# Out:
# 0    21
# 1    17
# 2    18
# Name: email, dtype: int64

# %%
df.apply(len, axis='rows')
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(pd.Series.min)
# Out:
# first                   Haseeb
# last                     Jamal
# email    haseebtariq@gmail.com
# dtype: str

# %%
df.apply(lambda x: x.min())
# Out:
# first                   Haseeb
# last                     Jamal
# email    haseebtariq@gmail.com
# dtype: str

# %%
df.map(len)
# Out:
#    first  last  email
# 0      6     5     21
# 1      7     5     17
# 2      8     6     18

# %%
df.map(str.lower)
# Out:
#       first    last                  email
# 0    haseeb   tariq  haseebtariq@gmail.com
# 1   zeeshan   jamal      zeeshan@gmail.com
# 2  sharjeel  sheikh     sharjeel@gmail.com

# %%
df['first'].map({'Haseeb' : 'Muneeb', 'Zeeshan' : 'Arham', 'Sharjeel' : 'Sultan'})
# Out:
# 0    Muneeb
# 1     Arham
# 2    Sultan
# Name: first, dtype: str

# %%
df['first'] = df['first'].replace({'Haseeb' : 'Muneeb', 'Zeeshan' : 'Arham', 'Sharjeel' : 'Sultan'})

# %%
df
# Out:
#     first    last                  email
# 0  Muneeb   Tariq  haseebtariq@gmail.com
# 1   Arham   Jamal      zeeshan@gmail.com
# 2  Sultan  Sheikh     sharjeel@gmail.com

# %%
df['first']+ '' + df['last']
# Out:
# 0     MuneebTariq
# 1      ArhamJamal
# 2    SultanSheikh
# dtype: str

# %%
df['full_name'] = df['first']+ ' ' + df['last']

# %%
df
# Out:
#     first    last                  email      full_name
# 0  Muneeb   Tariq  haseebtariq@gmail.com   Muneeb Tariq
# 1   Arham   Jamal      zeeshan@gmail.com    Arham Jamal
# 2  Sultan  Sheikh     sharjeel@gmail.com  Sultan Sheikh

# %%
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#                    email      full_name
# 0  haseebtariq@gmail.com   Muneeb Tariq
# 1      zeeshan@gmail.com    Arham Jamal
# 2     sharjeel@gmail.com  Sultan Sheikh

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#         0       1
# 0  Muneeb   Tariq
# 1   Arham   Jamal
# 2  Sultan  Sheikh

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                    email      full_name   first    last
# 0  haseebtariq@gmail.com   Muneeb Tariq  Muneeb   Tariq
# 1      zeeshan@gmail.com    Arham Jamal   Arham   Jamal
# 2     sharjeel@gmail.com  Sultan Sheikh  Sultan  Sheikh
