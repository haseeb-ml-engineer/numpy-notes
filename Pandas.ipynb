# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\Pandas\data\survey_results_public.csv', low_memory=False, index_col='ResponseId')
schema_df = pd.read_csv(r'C:\Users\HP\Desktop\Pandas\data\survey_results_schema.csv', index_col="qname")

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.shape
# Out:
# (49191, 171)

# %%
df.info(verbose= True, show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 1 to 49191
# Data columns (total 171 columns):
#  #    Column                                    Non-Null Count  Dtype
# ---   ------                                    --------------  -----
#  0    MainBranch                                49191 non-null  str
#  1    Age                                       49191 non-null  str
#  2    EdLevel                                   48149 non-null  str
#  3    Employment                                48339 non-null  str
#  4    EmploymentAddl                            44875 non-null  str
#  5    WorkExp                                   42893 non-null  float64
#  6    LearnCodeChoose                           46858 non-null  str
#  7    LearnCode                                 33556 non-null  str
#  8    LearnCodeAI                               45201 non-null  str
#  9    AILearnHow                                28257 non-null  str
# ...

# %%
pd.set_option('display.max_columns' , None)
pd.set_option('display.max_rows' , 170)

# %%
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# ...

# %%
df.shape
# Out:
# (49191, 171)

# %%
pd.set_option('display.max_columns', None)

# %%
print(list(df.columns))
# Out:
# ['MainBranch', 'Age', 'EdLevel', 'Employment', 'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode', 'LearnCodeAI', 'AILearnHow', 'YearsCode', 'DevType', 'OrgSize', 'ICorPM', 'RemoteWork', 'PurchaseInfluence', 'TechEndorseIntro', 'TechEndorse_1', 'TechEndorse_2', 'TechEndorse_3', 'TechEndorse_4', 'TechEndorse_5', 'TechEndorse_6', 'TechEndorse_7', 'TechEndorse_8', 'TechEndorse_9', 'TechEndorse_13', 'TechEndorse_13_TEXT', 'TechOppose_1', 'TechOppose_2', 'TechOppose_3', 'TechOppose_5', 'TechOppose_7', 'TechOppose_9', 'TechOppose_11', 'TechOppose_13', 'TechOppose_16', 'TechOppose_15', 'TechOppose_15_TEXT', 'Industry', 'JobSatPoints_1', 'JobSatPoints_2', 'JobSatPoints_3', 'JobSatPoints_4', 'JobSatPoints_5', 'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11', 'JobSatPoints_13', 'JobSatPoints_14', 'JobSatPoints_15', 'JobSatPoints_16', 'JobSatPoints_15_TEXT', 'AIThreat', 'NewRole', 'ToolCountWork', 'ToolCountPersonal', 'Country
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed                                                33750
# Independent contractor, freelancer, or self-employed     6708
# Student                                                  4428
# Not employed                                             2227
# Retired                                                   708
# I prefer not to say                                       518
# Name: count, dtype: int64

# %%
df.loc[0:2, 'Employment':'LearnCode']
# Out:
#            Employment                                   EmploymentAddl  \
# ResponseId
# 1            Employed  Caring for dependents (children, elderly, etc.)
# 2            Employed                                              NaN
#
#             WorkExp                                    LearnCodeChoose  \
# ResponseId
# 1               8.0  Yes, I am not new to coding but am learning ne...
# 2               2.0  Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...

# %%
schema_df.loc['LearnCodeChoose', 'question']
# Out:
# 'Did you begin learning to code or learn a new coding skill/programming language in the last year?'

# %%
# schema_df.sort_index(ascending=False)
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
high_sal = (df['ConvertedCompYearly'] > 70000)

# %%
# df.loc[high_sal, ['Country', 'LanguageAdmired', 'ConvertedCompYearly']]
# countries = ['United States of America', 'India', 'Canada', 'United Kingdom']

# %%
# df.loc[filt, 'Country']

# %%
# filt = pd.DataFrame(filt)

# %%
# df['Country'].value_counts()

# %%
# filt = df[df['Country'].isin(countries)]

# %%
# filt['Country'].value_counts()

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
# df['LanguageAdmired']

# %%
filt
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 49187    False
# 49188    False
# 49189    False
# 49190    False
# 49191    False
# Name: LanguageHaveWorkedWith, Length: 49191, dtype: bool

# %%
df.rename(columns={'ConvertedCompYearly' : 'SalaryUSD'})
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df['ConvertedCompYearly']
# Out:
# ResponseId
# 1         61256.0
# 2        104413.0
# 3         53061.0
# 4         36197.0
# 5         60000.0
#            ...
# 49187         NaN
# 49188         NaN
# 49189         NaN
# 49190         NaN
# 49191         NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
df['Employment'].map({'Yes':True, 'No':False})
# Out:
# ResponseId
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 49187    NaN
# 49188    NaN
# 49189    NaN
# 49190    NaN
# 49191    NaN
# Name: Employment, Length: 49191, dtype: object

# %%
df.isnull()
# Out:
#             MainBranch    Age  EdLevel  Employment  EmploymentAddl  WorkExp  \
# ResponseId
# 1                False  False    False       False           False    False
# 2                False  False    False       False            True    False
# 3                False  False    False       False           False    False
# 4                False  False    False       False           False    False
# 5                False  False    False       False           False    False
# ...                ...    ...      ...         ...             ...      ...
# 49187            False  False    False       False            True     True
# 49188            False  False    False       False           False    False
# 49189            False  False    False       False           False    False
# 49190            False  False    False       False           False    False
# 49191            False  False    False       False           False     True
#
# ...

# %%
df.isnull().sum()
# Out:
# MainBranch                 0
# Age                        0
# EdLevel                 1042
# Employment               852
# EmploymentAddl          4316
#                        ...
# AIAgentExtWrite        48332
# AIHuman                19997
# AIOpen                 26651
# ConvertedCompYearly    25244
# JobSat                 22521
# Length: 171, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4437549)

# %% [markdown]
# ## Filling Null Values

# %%
df2 = df.fillna(value = 0)

# %%
df2
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %% [markdown]
# df2.isnull().sum().sum()

# %%
df3 = df.fillna(value = 5)

# %%
df3
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %% [markdown]
# ## Filling Null Values with previous values

# %%
df4 = df.ffill()

# %%
df4.isnull().sum().sum()
# Out:
# np.int64(3363)

# %% [markdown]
# ## Filling Null values with next valid values

# %%
df5 = df.bfill()

# %%
df5.isnull().sum().sum()
# Out:
# np.int64(3023)
